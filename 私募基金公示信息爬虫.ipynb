# %%
import requests
from bs4 import BeautifulSoup
URL = 'https://gs.amac.org.cn/amac-infodisc/res/pof/fund/1711031653100686.html'
page = requests.get(URL, verify = False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
bs = BeautifulSoup(page.content, 'html.parser')

# %%
print(bs.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,user-scalable=no" name="viewport"/>
#   <meta content="ie=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    私募基金公示 - 中国证券投资基金业协会
#   </title>
#   <link href="../../common/css/font.css" rel="stylesheet"/>
#   <link href="../../common/css/reset.css" rel="stylesheet"/>
#   <link href="../../common/css/common.css" rel="stylesheet"/>
#   <link href="../../common/css/phone.css" rel="stylesheet"/>
#   <script src="../../common/js/jquery-1.7.2.min.js">
#   </script>
#   <script src="../../common/js/common.js">
#   </script>
#   <script src="../../common/js/jquery.select-1.3.6.js">
#   </script>
#   <link href="../../common/css/unit.css" rel="stylesheet" type="text/css">
#    <link href="../../common/css/grid.css" rel="stylesheet" type="text/css">
#     <link href="../../common/css/global.css" rel="stylesheet" type="text/css">
# ...

# %%
print(bs.title)
# Out:
# <title>私募基金公示 - 中国证券投资基金业协会</title>

# %%
for item in bs.find_all("td"):
    if item.a != None:
        name = item.a.string

# %%
for item in bs.find_all("td"):
    print(item.string)
# Out:
# 基金名称:
#
#                                 天津盈诚集智FOF组合6号私募基金
#
# None
# 基金编号:
# SX9589
# None
# 成立时间:
# 2017-10-24
# 备案时间:
# 2017-11-03
# 基金备案阶段:
# 暂行办法实施后成立的基金
# 基金类型:
# 私募证券投资基金
# 币种:
# 人民币现钞
# 基金管理人名称:
# None
# 管理类型:
# 受托管理
# 托管人名称:
# 宁波银行股份有限公司
# 运作状态:
# 正在运作
# 基金信息最后更新时间:
# 2019-08-07
# 基金业协会特别提示（针对基金）:
# None
# 当月月报:
# None
# 季报:
# None
# 半年报:
# None
# 年报:
# None

# %%
dict = {}
i = 0
for item in bs.find_all("td"):
    if item.string != None and i < 6:
        if i%2 ==0:
            a = item.string.replace(" ","").replace("\n","")
        if i%2 ==1:
            dict[a] = item.string.replace(" ","").replace("\n","")
        i = i + 1
    elif i>= 6:
        if i%2 ==0:
            a = item.string
        if i%2 ==1:
            dict[a] = item.string
        i = i + 1
    if item.a != None:
        name = item.a.string
dict['基金管理人名称:'] = name
dict
# Out:
# {'基金名称:': '天津盈诚集智FOF组合6号私募基金',
#  '基金编号:': 'SX9589',
#  '成立时间:': '2017-10-24',
#  '备案时间:': '2017-11-03',
#  '基金备案阶段:': '暂行办法实施后成立的基金',
#  '基金类型:': '私募证券投资基金',
#  '币种:': '人民币现钞',
#  '基金管理人名称:': '天津盈诚投资管理有限公司',
#  '管理类型:': '受托管理',
#  '托管人名称:': '宁波银行股份有限公司',
#  '运作状态:': '正在运作',
#  '基金信息最后更新时间:': '2019-08-07',
#  '基金业协会特别提示（针对基金）:': None,
#  '当月月报:': None,
#  '季报:': None,
#  '半年报:': None,
#  '年报:': None}
